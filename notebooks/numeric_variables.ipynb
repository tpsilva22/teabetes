# %% [markdown]
# In this notebook, an exploratory analysis will be performed on all numerical variables.
#
# For each variable, the following statistics will be calculated:
#
#     minimum
#     maximum
#     mean
#     median
#     standard deviation
#     quartiles
#     asymmetry
#
# And the following plots will be generated:
#
#     Histogram
#     Boxplot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

diabetes = pd.read_csv("../data/diabetes_dataset_new_variables.csv")

# %% [markdown]
# Variable: age

# %%
diabetes["age"].describe()
# Out:
# count    100000.00000
# mean         50.12041
# std          15.60460
# min          18.00000
# 25%          39.00000
# 50%          50.00000
# 75%          61.00000
# max          90.00000
# Name: age, dtype: float64

# %%
diabetes["age"].skew()
# Out:
# np.float64(0.08268602466165732)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["age"], bins=72)
plt.title("Histogram - Age", fontsize=20)
plt.xlabel("Age", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(y=diabetes["age"], width=0.5)
plt.title("Boxplot - Age", fontsize=20)
plt.ylabel("Age", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# Variable: bmi

# %%
diabetes["bmi"].describe()
# Out:
# count    100000.000000
# mean         25.612653
# std           3.586705
# min          15.000000
# 25%          23.200000
# 50%          25.600000
# 75%          28.000000
# max          39.200000
# Name: bmi, dtype: float64

# %%
diabetes["bmi"].skew()
# Out:
# np.float64(0.006295654533861601)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["bmi"], bins=25)
plt.title("Histogram - BMI", fontsize=16)
plt.xlabel("BMI", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 12))
sns.boxplot(y=diabetes["bmi"], width=0.5)
plt.title("Boxplot - BMI", fontsize=16)
plt.ylabel("BMI", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# Variable: waist_to_hip_ratio

# %%
diabetes["waist_to_hip_ratio"].describe()
# Out:
# count    100000.000000
# mean          0.856078
# std           0.046837
# min           0.670000
# 25%           0.820000
# 50%           0.860000
# 75%           0.890000
# max           1.060000
# Name: waist_to_hip_ratio, dtype: float64

# %%
diabetes["waist_to_hip_ratio"].skew()
# Out:
# np.float64(0.005583868429741822)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["waist_to_hip_ratio"],bins=20)
plt.title("Histogram - Waist to Hip Ratio", fontsize=16)
plt.xlabel("Waist to Hip Ratio", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(y=diabetes["waist_to_hip_ratio"], width=0.5)
plt.title("Boxplot - Waist to Hip Ratio", fontsize=16)
plt.ylabel("Waist to Hip Ratio", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: diet_score

# %%
diabetes["diet_score"].describe()
# Out:
# count    100000.000000
# mean          5.994787
# std           1.780954
# min           0.000000
# 25%           4.800000
# 50%           6.000000
# 75%           7.200000
# max          10.000000
# Name: diet_score, dtype: float64

# %%
diabetes["diet_score"].skew()
# Out:
# np.float64(-0.07025109543372467)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["diet_score"],bins=10)
plt.title("Histogram - Diet Score", fontsize=16)
plt.xlabel("Diet Score", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 10))
sns.boxplot(y=diabetes["diet_score"], width=0.5)
plt.title("Boxplot - Diet Score", fontsize=20)
plt.ylabel("Diet Score", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: sleep_hours_per_day

# %%
diabetes["sleep_hours_per_day"].describe()
# Out:
# count    100000.000000
# mean          6.997818
# std           1.094622
# min           3.000000
# 25%           6.300000
# 50%           7.000000
# 75%           7.700000
# max          10.000000
# Name: sleep_hours_per_day, dtype: float64

# %%
diabetes["sleep_hours_per_day"].skew()
# Out:
# np.float64(-0.012613494106121443)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["sleep_hours_per_day"],bins=7)
plt.title("Histogram - Sleep Hours per Day", fontsize=16)
plt.xlabel("Sleep Hours per Day", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 8))
sns.boxplot(y=diabetes["sleep_hours_per_day"], width=0.5)
plt.title("Boxplot - Sleep Hours per Day", fontsize=20)
plt.ylabel("Sleep Hours per Day", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: screen_time_hours_per_day

# %%
diabetes["screen_time_hours_per_day"].describe()
# Out:
# count    100000.000000
# mean          5.996468
# std           2.468406
# min           0.500000
# 25%           4.300000
# 50%           6.000000
# 75%           7.700000
# max          16.800000
# Name: screen_time_hours_per_day, dtype: float64

# %%
diabetes["screen_time_hours_per_day"].skew()
# Out:
# np.float64(0.08257264640857293)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["screen_time_hours_per_day"],bins=17)
plt.title("Histogram - Screen Time Hours per Day", fontsize=16)
plt.xlabel("Screen Time Hours per Day", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 10))
sns.boxplot(y=diabetes["screen_time_hours_per_day"], width=0.5)
plt.title("Boxplot - Screen Time Hours per Day", fontsize=20)
plt.ylabel("Screen Time Hours per Day", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: alcohol_consumption_per_week

# %%
diabetes["alcohol_consumption_per_week"].describe()
# Out:
# count    100000.000000
# mean          2.003670
# std           1.417779
# min           0.000000
# 25%           1.000000
# 50%           2.000000
# 75%           3.000000
# max          10.000000
# Name: alcohol_consumption_per_week, dtype: float64

# %%
diabetes["alcohol_consumption_per_week"].skew()
# Out:
# np.float64(0.7033434878834333)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["alcohol_consumption_per_week"],bins=10)
plt.title("Histogram - Alcohol Consumption per Week", fontsize=16)
plt.xlabel("Alcohol Consumption per Week", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(y=diabetes["alcohol_consumption_per_week"], width=0.5)
plt.title("Boxplot - Alcohol Consumption per Week", fontsize=20)
plt.ylabel("Alcohol Consumption per Week    ", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: physical_activity_minutes_per_week

# %%
diabetes["physical_activity_minutes_per_week"].describe()
# Out:
# count    100000.000000
# mean        118.911640
# std          84.409662
# min           0.000000
# 25%          57.000000
# 50%         100.000000
# 75%         160.000000
# max         833.000000
# Name: physical_activity_minutes_per_week, dtype: float64

# %%
diabetes["physical_activity_minutes_per_week"].skew()
# Out:
# np.float64(1.3899701983551658)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["physical_activity_minutes_per_week"],bins=8)
plt.title("Histogram - Physical Activity Minutes per Week", fontsize=16)
plt.xlabel("Physical Activity Minutes per Week", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 10))
sns.boxplot(y=diabetes["physical_activity_minutes_per_week"], width=0.5)
plt.title("Boxplot - Physical Activity Minutes per Week", fontsize=20)
plt.ylabel("Physical Activity Minutes per Week    ", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: systolic_bp

# %%
diabetes["systolic_bp"].describe()
# Out:
# count    100000.000000
# mean        115.799610
# std          14.284073
# min          90.000000
# 25%         106.000000
# 50%         116.000000
# 75%         125.000000
# max         179.000000
# Name: systolic_bp, dtype: float64

# %%
diabetes["systolic_bp"].skew()
# Out:
# np.float64(0.2187561691882406)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["systolic_bp"],bins=20)
plt.title("Histogram - Systolic Blood Pressure", fontsize=16)
plt.xlabel("Systolic Blood Pressure", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 10))
sns.boxplot(y=diabetes["systolic_bp"], width=0.5)
plt.title("Boxplot - Systolic Blood Pressure", fontsize=20)
plt.ylabel("Systolic Blood Pressure    ", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: diastolic_bp

# %%
diabetes["diastolic_bp"].describe()
# Out:
# count    100000.00000
# mean         75.23249
# std           8.20425
# min          50.00000
# 25%          70.00000
# 50%          75.00000
# 75%          81.00000
# max         110.00000
# Name: diastolic_bp, dtype: float64

# %%
diabetes["diastolic_bp"].skew()
# Out:
# np.float64(0.00707400236884844)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["diastolic_bp"],bins=30)
plt.title("Histogram - Diastolic Blood Pressure", fontsize=16)
plt.xlabel("Diastolic Blood Pressure", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 10))
sns.boxplot(y=diabetes["diastolic_bp"], width=0.5)
plt.title("Boxplot - Diastolic Blood Pressure", fontsize=20)
plt.ylabel("Diastolic Blood Pressure    ", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: heart_rate

# %%
diabetes["heart_rate"].describe()
# Out:
# count    100000.000000
# mean         69.632870
# std           8.371954
# min          40.000000
# 25%          64.000000
# 50%          70.000000
# 75%          75.000000
# max         105.000000
# Name: heart_rate, dtype: float64

# %%
diabetes["heart_rate"].skew()
# Out:
# np.float64(-0.01681070641766614)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["heart_rate"],bins=20)
plt.title("Histogram - Heart Rate", fontsize=16)
plt.xlabel("Heart Rate", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 10))
sns.boxplot(y=diabetes["heart_rate"], width=0.5)
plt.title("Boxplot - Heart Rate", fontsize=20)
plt.ylabel("Heart Rate    ", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: cholesterol_total

# %%
diabetes["cholesterol_total"].describe()
# Out:
# count    100000.000000
# mean        185.978110
# std          32.013005
# min         100.000000
# 25%         164.000000
# 50%         186.000000
# 75%         208.000000
# max         318.000000
# Name: cholesterol_total, dtype: float64

# %%
diabetes["cholesterol_total"].skew()
# Out:
# np.float64(0.033571836773928)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["cholesterol_total"],bins=10)
plt.title("Histogram - Cholesterol Total", fontsize=16)
plt.xlabel("Cholesterol Total", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 12))
sns.boxplot(y=diabetes["cholesterol_total"], width=0.5)
plt.title("Boxplot - Cholesterol Total", fontsize=20)
plt.ylabel("Cholesterol Total    ", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: hdl_cholesterol

# %%
diabetes["hdl_cholesterol"].describe()
# Out:
# count    100000.000000
# mean         54.042790
# std          10.267374
# min          20.000000
# 25%          47.000000
# 50%          54.000000
# 75%          61.000000
# max          98.000000
# Name: hdl_cholesterol, dtype: float64

# %%
diabetes["hdl_cholesterol"].skew()
# Out:
# np.float64(-0.0026260114396779556)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["hdl_cholesterol"],bins=16)
plt.title("Histogram - HDL Cholesterol", fontsize=16)
plt.xlabel("HDL Cholesterol", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 12))
sns.boxplot(y=diabetes["hdl_cholesterol"], width=0.5)
plt.title("Boxplot - HDL Cholesterol", fontsize=20)
plt.ylabel("HDL Cholesterol    ", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: ldl_cholesterol

# %%
diabetes["ldl_cholesterol"].describe()
# Out:
# count    100000.000000
# mean        103.000430
# std          33.390256
# min          50.000000
# 25%          78.000000
# 50%         102.000000
# 75%         126.000000
# max         263.000000
# Name: ldl_cholesterol, dtype: float64

# %%
diabetes["ldl_cholesterol"].skew()
# Out:
# np.float64(0.3199014992145796)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["hdl_cholesterol"],bins=16)
plt.title("Histogram - HDL Cholesterol", fontsize=16)
plt.xlabel("HDL Cholesterol", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 12))
sns.boxplot(y=diabetes["hdl_cholesterol"], width=0.5)
plt.title("Boxplot - HDL Cholesterol", fontsize=20)
plt.ylabel("HDL Cholesterol    ", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: triglycerides

# %%
diabetes["triglycerides"].describe()
# Out:
# count    100000.000000
# mean        121.462650
# std          43.372619
# min          30.000000
# 25%          91.000000
# 50%         121.000000
# 75%         151.000000
# max         344.000000
# Name: triglycerides, dtype: float64

# %%
diabetes["triglycerides"].skew()
# Out:
# np.float64(0.10403523983394188)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["triglycerides"],bins=14)
plt.title("Histogram - Triglycerides", fontsize=16)
plt.xlabel("Triglycerides  ", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 12))
sns.boxplot(y=diabetes["triglycerides"], width=0.5)
plt.title("Boxplot - Triglycerides", fontsize=20)
plt.ylabel("Triglycerides    ", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: glucose_fasting

# %%
diabetes["glucose_fasting"].describe()
# Out:
# count    100000.00000
# mean        111.11712
# std          13.59561
# min          60.00000
# 25%         102.00000
# 50%         111.00000
# 75%         120.00000
# max         172.00000
# Name: glucose_fasting, dtype: float64

# %%
diabetes["glucose_fasting"].skew()
# Out:
# np.float64(0.046037196958746765)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["glucose_fasting"],bins=10)
plt.title("Histogram - Glucose Fasting", fontsize=16)
plt.xlabel("Glucose Fasting  ", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 12))
sns.boxplot(y=diabetes["glucose_fasting"], width=0.5)
plt.title("Boxplot - Glucose Fasting", fontsize=20)
plt.ylabel("Glucose Fasting", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: insulin_level

# %%
diabetes["insulin_level"].describe()
# Out:
# count    100000.000000
# mean          9.061242
# std           4.954060
# min           2.000000
# 25%           5.090000
# 50%           8.790000
# 75%          12.450000
# max          32.220000
# Name: insulin_level, dtype: float64

# %%
diabetes["insulin_level"].skew()
# Out:
# np.float64(0.4224750383270174)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["insulin_level"],bins=12)
plt.title("Histogram - Insulin Level", fontsize=16)
plt.xlabel("Insulin Level  ", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 12))
sns.boxplot(y=diabetes["insulin_level"], width=0.5)
plt.title("Boxplot - Insulin Level", fontsize=20)
plt.ylabel("Insulin Level", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: hba1c

# %%
diabetes["hba1c"].describe()
# Out:
# count    100000.000000
# mean          6.520776
# std           0.813921
# min           4.000000
# 25%           5.970000
# 50%           6.520000
# 75%           7.070000
# max           9.800000
# Name: hba1c, dtype: float64

# %%
diabetes["hba1c"].skew()
# Out:
# np.float64(0.03196866822260478)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["hba1c"],bins=12)
plt.title("Histogram - Glycated Hemoglobin", fontsize=16)
plt.xlabel("Glycated Hemoglobin", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 12))
sns.boxplot(y=diabetes["hba1c"], width=0.5)
plt.title("Boxplot - Glycated Hemoglobin", fontsize=20)
plt.ylabel("Glycated Hemoglobin", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: diabetes_risk_score

# %%
diabetes["diabetes_risk_score"].describe()
# Out:
# count    100000.000000
# mean         30.222362
# std           9.061505
# min           2.700000
# 25%          23.800000
# 50%          29.000000
# 75%          35.600000
# max          67.200000
# Name: diabetes_risk_score, dtype: float64

# %%
diabetes["diabetes_risk_score"].skew()
# Out:
# np.float64(0.5146103521956422)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["diabetes_risk_score"],bins=14)
plt.title("Histogram - Diabetes Risk Score", fontsize=16)
plt.xlabel("Diabetes Risk Score", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 12))
sns.boxplot(y=diabetes["diabetes_risk_score"], width=0.5)
plt.title("Boxplot - Diabetes Risk Score", fontsize=20)
plt.ylabel("Diabetes Risk Score", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: glucose_postprandial

# %%
diabetes["glucose_postprandial"].describe()
# Out:
# count    100000.000000
# mean        160.035050
# std          30.935472
# min          70.000000
# 25%         139.000000
# 50%         160.000000
# 75%         181.000000
# max         287.000000
# Name: glucose_postprandial, dtype: float64

# %%
diabetes["glucose_postprandial"].skew()
# Out:
# np.float64(0.027832392747424713)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["glucose_postprandial"],bins=10)
plt.title("Histogram - Postprandial Glucose", fontsize=16)
plt.xlabel("Postprandial Glucose", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 12))
sns.boxplot(y=diabetes["glucose_postprandial"], width=0.5)
plt.title("Boxplot - Postprandial Glucose", fontsize=20)
plt.ylabel("Postprandial Glucose", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable : insulin_resistance

# %%
diabetes["insulin_resistance"].describe()
# Out:
# count    100000.000000
# mean          2.503128
# std           1.437741
# min           0.296296
# 25%           1.360123
# 50%           2.378333
# 75%           3.439136
# max          10.343556
# Name: insulin_resistance, dtype: float64

# %%
diabetes["insulin_resistance"].skew()
# Out:
# np.float64(0.5876140763075745)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["insulin_resistance"],bins=20)
plt.title("Histogram - Insulin Resistance", fontsize=16)
plt.xlabel("Insulin Resistance", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 12))
sns.boxplot(y=diabetes["insulin_resistance"], width=0.5)
plt.title("Boxplot - Insulin Resistance", fontsize=20)
plt.ylabel("Insulin Resistance", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: glycemia_spike

# %%
# Only considers non-negative values for glycemia spike, as negative values may not be meaningful in this context

glycemia_spike_plot = diabetes["glycemia_spike"].where(diabetes["glycemia_spike"] >= 0)
glycemia_spike_plot.describe()
# Out:
# count    97405.000000
# mean        50.476485
# std         23.838509
# min          0.000000
# 25%         33.000000
# 50%         50.000000
# 75%         67.000000
# max        153.000000
# Name: glycemia_spike, dtype: float64

# %%
glycemia_spike_plot.skew()
# Out:
# np.float64(0.24252384470724855)

# %%
# Histogram
glycemia_spike_plot = diabetes["glycemia_spike"].where(diabetes["glycemia_spike"] >= 0)
plt.figure(figsize=(12, 5))
sns.histplot(glycemia_spike_plot,bins=32)
plt.title("Histogram - Glycemia Spike", fontsize=16)
plt.xlabel("Glycemia Spike", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 12))
sns.boxplot(y=glycemia_spike_plot, width=0.5)
plt.title("Boxplot - Glycemia Spike", fontsize=20)
plt.ylabel("Glycemia Spike", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: obesity_index

# %%
diabetes["obesity_index"].describe()
# Out:
# count    100000.000000
# mean         22.055066
# std           4.069482
# min          10.050000
# 25%          19.256000
# 50%          21.924000
# 75%          24.708000
# max          40.664000
# Name: obesity_index, dtype: float64

# %%
diabetes["obesity_index"].skew()
# Out:
# np.float64(0.2145152801004734)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["obesity_index"],bins=12)
plt.title("Histogram - Obesity Index", fontsize=16)
plt.xlabel("Obesity Index", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 12))
sns.boxplot(y=diabetes["obesity_index"], width=0.5)
plt.title("Boxplot - Obesity Index", fontsize=20)
plt.ylabel("Obesity Index", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: pulse_pressure

# %%
pulse_pressure_plot = diabetes["pulse_pressure"].where(diabetes["pulse_pressure"] >= 0)
pulse_pressure_plot.describe()
# Out:
# count    99884.000000
# mean        40.617586
# std         15.406254
# min          0.000000
# 25%         30.000000
# 50%         40.000000
# 75%         51.000000
# max        117.000000
# Name: pulse_pressure, dtype: float64

# %%
pulse_pressure_plot.skew()
# Out:
# np.float64(0.15760403671377718)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(pulse_pressure_plot,bins=12)
plt.title("Histogram - Pulse Pressure", fontsize=16)
plt.xlabel("Pulse Pressure", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 12))
sns.boxplot(y=pulse_pressure_plot, width=0.5)
plt.title("Boxplot - Pulse Pressure", fontsize=20)
plt.ylabel("Pulse Pressure", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: map

# %%
diabetes["map"].describe()
# Out:
# count    100000.000000
# mean         88.754863
# std           7.727380
# min          63.333333
# 25%          83.333333
# 50%          88.666667
# 75%          94.000000
# max         122.666667
# Name: map, dtype: float64

# %%
diabetes["map"].skew()
# Out:
# np.float64(0.08269539573413426)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["map"],bins=10)
plt.title("Histogram - Mean Arterial Pressure", fontsize=16)
plt.xlabel("Mean Arterial Pressure", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 12))
sns.boxplot(y=diabetes["map"], width=0.5)
plt.title("Boxplot - Mean Arterial Pressure", fontsize=20)
plt.ylabel("Mean Arterial Pressure", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: ratio_ldl_hdl

# %%
diabetes["ratio_ldl_hdl"].describe()
# Out:
# count    100000.000000
# mean          2.027440
# std           0.924405
# min           0.520833
# 25%           1.357143
# 50%           1.880000
# 75%           2.514286
# max          11.300000
# Name: ratio_ldl_hdl, dtype: float64

# %%
diabetes["ratio_ldl_hdl"].skew()
# Out:
# np.float64(1.2637190678936296)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["ratio_ldl_hdl"],bins=12)
plt.title("Histogram - LDL/HDL Ratio", fontsize=16)
plt.xlabel("LDL/HDL Ratio", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 12))
sns.boxplot(y=diabetes["ratio_ldl_hdl"], width=0.5)
plt.title("Boxplot - LDL/HDL Ratio", fontsize=20)
plt.ylabel("LDL/HDL Ratio", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# variable: sedentary_ratio

# %% [markdown]
# variable: clinical_risk_score

# %%
diabetes["clinical_risk_score"].describe()
# Out:
# count    100000.000000
# mean          0.768820
# std           0.976732
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max           4.000000
# Name: clinical_risk_score, dtype: float64

# %%
diabetes["clinical_risk_score"].skew()
# Out:
# np.float64(1.011172072678428)

# %%
# Histogram
plt.figure(figsize=(12, 5))
sns.histplot(diabetes["clinical_risk_score"],bins=8)
plt.title("Histogram - Clinical Risk Score", fontsize=16)
plt.xlabel("Clinical Risk Score", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()

# Boxplot
plt.figure(figsize=(12, 12))
sns.boxplot(y=diabetes["clinical_risk_score"], width=0.5)
plt.title("Boxplot - Clinical Risk Score", fontsize=20)
plt.ylabel("Clinical Risk Score", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.show()
