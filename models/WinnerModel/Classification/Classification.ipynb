# %% [markdown]
# # **Classification Winner Summary**
#
# This table consolidates the winning run for each classification algorithm, using only the test metrics reported in each notebook.
#
# | Algorithm | Winning run | Accuracy (Test) | Recall (Test) | F1 (Test) | Fit Time | Status |
# |---|---|---:|---:|---:|---:|---|
# | Decision Tree | DT_Regularized_Baseline | 0.91740 | 0.86833 | 0.92655 | 0.67s | Valid |
# | Naive Bayes | NB_Standard_Optuna | 0.82365 | 0.82633 | 0.84901 | 24.94s | Valid |
# | Logistic Regression | LogReg_Normalization_Optuna | 0.81160 | 0.91558 | 0.85362 | 17.52s | Valid |
# | Perceptron | Perceptron_Optuna | 0.89370 | 0.82283 | 0.90281 | 8.79s | Valid |
# | Bagging Classifier | Bagging_LR_Baseline | 0.80500 | 0.92017 | 0.84991 | 23.49s | Valid |
# | Random Forest | RFC_Optuna | 0.91675 | 0.86858 | 0.92604 | 117.12s | Valid |
# | AdaBoost | AdaBoost_Baseline | 0.91990 | 0.86650 | 0.92848 | 6.68s | Valid |
# | Gradient Boosting | GBC_Baseline_Defaults | 0.91985 | 0.86650 | 0.92843 | 27.41s | Valid |
# | XGBoost | XGB_Baseline_Defaults | 0.91755 | 0.86742 | 0.92660 | 0.45s | Valid |
# | Stacking | Stacking_Normalization_Champions | 0.91965 | 0.86675 | 0.92829 | 153.90s | Valid |
# | SVC | SVC_Normalization_Optuna_50k | 0.87564 | 0.88250 | 0.89491 | 696.13s | Disqualified: not run with 100000 rows |
# | K-NN | N/A | - | - | - | - | Disqualified: not run with 100000 rows |
#
# ## **Winner Selection Rule**
#
# Pick the run with the highest Recall on the test set, because clinical recall has 70% priority.
# If there is a tie, or if the Recall difference is smaller than 0.5%, use the highest F1-Score on the test set as the tiebreaker, with 30% weight, to avoid excessive false positives.
# Ignore Accuracy.
# If the tie still persists, choose the run with the lowest Fit Time.
#
# ## **Winner of Winners**
#
# Using the rule above, the overall winner among the valid classification champions is **Bagging_LR_Baseline**.
